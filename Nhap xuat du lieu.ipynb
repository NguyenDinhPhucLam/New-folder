# %%
#W2A1 
print("Hello World")
# Out:
# Hello World

# %%
#W2A2 
name = input("nhập tên của bạn:")
print("Xin chào", name)
# Out:
# Xin chào lâm

# %%
#W2A3 
a = int(input("nhập số nguyên:"))
b = int(input("nhập số nguyên:"))
tổng = a+b
hiệu = a-b
tích = a*b
phan_nguyen = a//b 
phan_du = a%b 
chia_thuc = a/b 
print("tổng:", tổng)
print("hiệu:", hiệu)
print("tích:", tích)
print("phần nguyên:", phan_nguyen)
print("phần dư:", phan_du)
print("chia thực:", chia_thuc)
# Out:
# tổng: 10
# hiệu: -2
# tích: 24
# phần nguyên: 0
# phần dư: 4
# chia thực: 0.6666666666666666

# %%
#W2A4
a1, b1, c1, a2, b2, c3 = map(float, input().split())
tb = (a1 + b1 + c1)*1 + (a2 + b2)*2 + c3*3
tb = tb/10
print(f"{tb:.1f}")
# Out:
# 5.2

# %%
#W2A5
a = int(input("nhập số nguyên"))
b = int(input("nhập số nguyên"))
mũ = a**b
print(mũ)
# Out:
# 8

# %%
#W2A6 
L = input()
print(ord(L))
print(L.upper())
# Out:
# 97
# A

# %%
#W2A7 
A = ((13**2)*3) + 5
B = 13**2*3 + 5
print("A=", A)
print("B=", B)
# Out:
# A= 512
# B= 512

# %%
#W2A8 
C = float(input())
F = (9/5)*C + 32
print("F=", F)
# Out:
# F= 133.16000000000003

# %%
#W2A9 

x = float(input("nhập giá đồng hồ:"))
tong_tien = 10 + x + 0.3*x + 0.1*x
print("tổng tiền = ", tong_tien)
# Out:
# tổng tiền =  24.0

# %%
#W2A10
a, b, c = input("nhập tên người:").split()
a, b, c = c, b, a 
print(f"Hi {a}, {b} and {c}")
# Out:
# Hi Helen, Alice and Bod

# %%
#W2A11
h = float(input("nhập số giờ:"))
p = float(input("nhập số phút:"))
h = h*3600
p = p*60
print("từ giờ sang giây =", h)
print("từ phút sang giây =", p)
# Out:
# từ giờ sang giây = 8280.0
# từ phút sang giây = 60.0

# %%
#W2A12
n = int(input("nhập độ dài của rubik:"))
so_mieng_dan = 6**n
print("số miếng dán =", so_mieng_dan)
# Out:
# số miếng dán = 216

# %%
#W2A13
a = int(input("nhập số nguyên dương:"))
b = int(input("nhập số nguyên dương:"))
if a>0 and b>0:
 tich = a * b 
 print(tich % 10)
else:
 print("không phải hai số nguyên dương")
# Out:
# 2

# %%
#W2A14
a = int(input())
b = int(input())
a, b = b, a 
print(a, b)
# Out:
# 5 4

# %%
#W2A15

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print("*\n**\n***")
# Out:
# *
# **
# ***

# %%
#W2A18
print("### # #     ### ###\n#    #    #    #    #\n#    #     #   #    #\n#    #    #    #    #\n#    # #       #    #")
# Out:
# ### # #     ### ###
# #    #    #    #    #
# #    #     #   #    #
# #    #    #    #    #
# #    # #       #    #

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch \nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range(10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
